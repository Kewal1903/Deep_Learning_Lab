# %% [markdown]
# # Name : Kewal Thacker
# # Date : 31/07/2025
# # Reg No. : 230968126
# # Deep Learning Lab 2 (Batch A1)

# %% [markdown]
# # Question 1 (Churn Modelling Dataset)

# %%
#Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.regularizers import l1, l2
import matplotlib.pyplot as plt
# Out:
# 2025-07-31 10:56:45.998267: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-31 10:56:46.022689: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753939606.051648  118457 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753939606.061058  118457 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1753939606.083381  118457 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1753939606.083411  118457 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1753939606.083416  118457 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1753939606.083418  118457 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-07-31 10:56:46.091165: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#Load the dataset
data = pd.read_csv("Churn_Modelling.csv")
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
# Drop irrelevant columns
data = data.drop(['RowNumber', 'CustomerId', 'Surname'], axis=1)

# One-hot encode categorical variables
data = pd.get_dummies(data, columns=['Geography', 'Gender'], drop_first=True)

# %%
# Separate features and target
X = data.drop('Exited', axis=1)
y = data['Exited']

# Scale features 
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Split data into train (80%), validation (10%), and test (10%)
X_train_val, X_test, y_train_val, y_test = train_test_split(X_scaled, y, test_size=0.1, random_state=42, stratify=y)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.1111, random_state=42, stratify=y_train_val)

print(f'Training samples: {X_train.shape[0]}, Validation samples: {X_val.shape[0]}, Test samples: {X_test.shape[0]}')
# Out:
# Training samples: 8000, Validation samples: 1000, Test samples: 1000

# %%
#build_model
def build_model(hidden_layers, units_per_layer, activation, reg_type=None, reg_value=0.01, learning_rate=0.001):
    model = Sequential()
    input_dim = X_train.shape[1]
    
    # Define regularizer
    regularizer = None
    if reg_type == 'l1':
        regularizer = l1(reg_value)
    elif reg_type == 'l2':
        regularizer = l2(reg_value)

    # Add first hidden layer with input dimension
    model.add(Dense(units_per_layer[0], activation=activation, kernel_regularizer=regularizer, input_dim=input_dim))
    
    # Add subsequent hidden layers if any
    for i in range(1, hidden_layers):
        if units_per_layer[i] > 0:
            model.add(Dense(units_per_layer[i], activation=activation, kernel_regularizer=regularizer))
    
    # Output layer (binary classification)
    model.add(Dense(1, activation='sigmoid'))
    
    # Compile model
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    
    return model

# %%
# Hyperparameter options
hidden_layer_configs = {
    1: [128, 0, 0],
    2: [128, 64, 0],
    3: [128, 64, 32]
}
epochs_list = [10, 20, 30]
activation_functions = ['sigmoid', 'relu']
regularization_options = [None, 'l1', 'l2']
learning_rates = [0.1, 0.01, 0.001]

results = []

for hidden_layers, units_per_layer in hidden_layer_configs.items():
    for epochs in epochs_list:
        for activation in activation_functions:
            for reg in regularization_options:
                for lr in learning_rates:
                    print(f'Training model with {hidden_layers} hidden layers, units {units_per_layer[:hidden_layers]}, '
                          f'epochs={epochs}, activation={activation}, regularization={reg}, learning_rate={lr}')
                    
                    model = build_model(hidden_layers, units_per_layer, activation, reg_type=reg, reg_value=0.001, learning_rate=lr)
                    
                    history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=epochs, batch_size=64, verbose=0)
                    
                    # Evaluate on validation data
                    y_val_pred_prob = model.predict(X_val).ravel()
                    y_val_pred = (y_val_pred_prob > 0.5).astype(int)
                    
                    acc = accuracy_score(y_val, y_val_pred)
                    prec = precision_score(y_val, y_val_pred)
                    rec = recall_score(y_val, y_val_pred)
                    
                    results.append({
                        'Hidden_Layers': hidden_layers,
                        'Units': units_per_layer[:hidden_layers],
                        'Epochs': epochs,
                        'Activation': activation,
                        'Regularization': reg,
                        'Learning_Rate': lr,
                        'Accuracy': acc,
                        'Precision': prec,
                        'Recall': rec,
                        'History': history
                    })
# Out:
# Training model with 1 hidden layers, units [128], epochs=10, activation=sigmoid, regularization=None, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1753939684.159996  118457 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10175 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1753939686.325986  124698 service.cc:152] XLA service 0x7f0068005cd0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1753939686.326033  124698 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2025-07-31 10:58:06.366220: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1753939686.570577  124698 cuda_dnn.cc:529] Loaded cuDNN version 91100
# I0000 00:00:1753939687.059475  124698 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# Training model with 1 hidden layers, units [128], epochs=10, activation=sigmoid, regularization=None, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# Training model with 1 hidden layers, units [128], epochs=10, activation=sigmoid, regularization=None, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# Training model with 1 hidden layers, units [128], epochs=10, activation=sigmoid, regularization=l1, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=10, activation=sigmoid, regularization=l1, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# Training model with 1 hidden layers, units [128], epochs=10, activation=sigmoid, regularization=l1, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=10, activation=sigmoid, regularization=l2, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=10, activation=sigmoid, regularization=l2, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=10, activation=sigmoid, regularization=l2, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# Training model with 1 hidden layers, units [128], epochs=10, activation=relu, regularization=None, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=10, activation=relu, regularization=None, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=10, activation=relu, regularization=None, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# Training model with 1 hidden layers, units [128], epochs=10, activation=relu, regularization=l1, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=10, activation=relu, regularization=l1, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=10, activation=relu, regularization=l1, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# Training model with 1 hidden layers, units [128], epochs=10, activation=relu, regularization=l2, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=10, activation=relu, regularization=l2, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=10, activation=relu, regularization=l2, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=20, activation=sigmoid, regularization=None, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=20, activation=sigmoid, regularization=None, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=20, activation=sigmoid, regularization=None, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=20, activation=sigmoid, regularization=l1, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# Training model with 1 hidden layers, units [128], epochs=20, activation=sigmoid, regularization=l1, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=20, activation=sigmoid, regularization=l1, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=20, activation=sigmoid, regularization=l2, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# Training model with 1 hidden layers, units [128], epochs=20, activation=sigmoid, regularization=l2, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=20, activation=sigmoid, regularization=l2, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# Training model with 1 hidden layers, units [128], epochs=20, activation=relu, regularization=None, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=20, activation=relu, regularization=None, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=20, activation=relu, regularization=None, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=20, activation=relu, regularization=l1, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=20, activation=relu, regularization=l1, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=20, activation=relu, regularization=l1, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=20, activation=relu, regularization=l2, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=20, activation=relu, regularization=l2, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=20, activation=relu, regularization=l2, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=30, activation=sigmoid, regularization=None, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=30, activation=sigmoid, regularization=None, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=30, activation=sigmoid, regularization=None, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=30, activation=sigmoid, regularization=l1, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=30, activation=sigmoid, regularization=l1, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=30, activation=sigmoid, regularization=l1, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=30, activation=sigmoid, regularization=l2, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=30, activation=sigmoid, regularization=l2, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=30, activation=sigmoid, regularization=l2, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=30, activation=relu, regularization=None, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=30, activation=relu, regularization=None, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=30, activation=relu, regularization=None, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=30, activation=relu, regularization=l1, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=30, activation=relu, regularization=l1, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=30, activation=relu, regularization=l1, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# Training model with 1 hidden layers, units [128], epochs=30, activation=relu, regularization=l2, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=30, activation=relu, regularization=l2, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 1 hidden layers, units [128], epochs=30, activation=relu, regularization=l2, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Training model with 2 hidden layers, units [128, 64], epochs=10, activation=sigmoid, regularization=None, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-07-31 11:11:51.415087: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_23', 24 bytes spill stores, 24 bytes spill loads
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step
# Training model with 2 hidden layers, units [128, 64], epochs=10, activation=sigmoid, regularization=None, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# Training model with 2 hidden layers, units [128, 64], epochs=10, activation=sigmoid, regularization=None, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# Training model with 2 hidden layers, units [128, 64], epochs=10, activation=sigmoid, regularization=l1, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# Training model with 2 hidden layers, units [128, 64], epochs=10, activation=sigmoid, regularization=l1, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# Training model with 2 hidden layers, units [128, 64], epochs=10, activation=sigmoid, regularization=l1, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# Training model with 2 hidden layers, units [128, 64], epochs=10, activation=sigmoid, regularization=l2, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# Training model with 2 hidden layers, units [128, 64], epochs=10, activation=sigmoid, regularization=l2, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# Training model with 2 hidden layers, units [128, 64], epochs=10, activation=sigmoid, regularization=l2, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# Training model with 2 hidden layers, units [128, 64], epochs=10, activation=relu, regularization=None, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-07-31 11:13:28.965351: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_173', 112 bytes spill stores, 112 bytes spill loads
#
# 2025-07-31 11:13:29.068422: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_173', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-07-31 11:13:29.095412: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_173', 8 bytes spill stores, 8 bytes spill loads
#
# 2025-07-31 11:13:29.352185: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_249', 80 bytes spill stores, 80 bytes spill loads
#
# 2025-07-31 11:13:31.931590: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_25', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-07-31 11:13:32.387911: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_25', 132 bytes spill stores, 132 bytes spill loads
#
# 2025-07-31 11:13:39.263677: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-07-31 11:13:39.354243: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_16', 12 bytes spill stores, 12 bytes spill loads
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step
# Training model with 2 hidden layers, units [128, 64], epochs=10, activation=relu, regularization=None, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# Training model with 2 hidden layers, units [128, 64], epochs=10, activation=relu, regularization=None, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# Training model with 2 hidden layers, units [128, 64], epochs=10, activation=relu, regularization=l1, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# Training model with 2 hidden layers, units [128, 64], epochs=10, activation=relu, regularization=l1, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# Training model with 2 hidden layers, units [128, 64], epochs=10, activation=relu, regularization=l1, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# Training model with 2 hidden layers, units [128, 64], epochs=10, activation=relu, regularization=l2, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# Training model with 2 hidden layers, units [128, 64], epochs=10, activation=relu, regularization=l2, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# Training model with 2 hidden layers, units [128, 64], epochs=10, activation=relu, regularization=l2, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# Training model with 2 hidden layers, units [128, 64], epochs=20, activation=sigmoid, regularization=None, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# Training model with 2 hidden layers, units [128, 64], epochs=20, activation=sigmoid, regularization=None, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# Training model with 2 hidden layers, units [128, 64], epochs=20, activation=sigmoid, regularization=None, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# Training model with 2 hidden layers, units [128, 64], epochs=20, activation=sigmoid, regularization=l1, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# Training model with 2 hidden layers, units [128, 64], epochs=20, activation=sigmoid, regularization=l1, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# Training model with 2 hidden layers, units [128, 64], epochs=20, activation=sigmoid, regularization=l1, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# Training model with 2 hidden layers, units [128, 64], epochs=20, activation=sigmoid, regularization=l2, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# Training model with 2 hidden layers, units [128, 64], epochs=20, activation=sigmoid, regularization=l2, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# Training model with 2 hidden layers, units [128, 64], epochs=20, activation=sigmoid, regularization=l2, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# Training model with 2 hidden layers, units [128, 64], epochs=20, activation=relu, regularization=None, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# Training model with 2 hidden layers, units [128, 64], epochs=20, activation=relu, regularization=None, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# Training model with 2 hidden layers, units [128, 64], epochs=20, activation=relu, regularization=None, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# Training model with 2 hidden layers, units [128, 64], epochs=20, activation=relu, regularization=l1, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# Training model with 2 hidden layers, units [128, 64], epochs=20, activation=relu, regularization=l1, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# ...
# Training model with 3 hidden layers, units [128, 64, 32], epochs=20, activation=relu, regularization=None, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Training model with 3 hidden layers, units [128, 64, 32], epochs=20, activation=relu, regularization=None, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Training model with 3 hidden layers, units [128, 64, 32], epochs=20, activation=relu, regularization=l1, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Training model with 3 hidden layers, units [128, 64, 32], epochs=20, activation=relu, regularization=l1, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Training model with 3 hidden layers, units [128, 64, 32], epochs=20, activation=relu, regularization=l1, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Training model with 3 hidden layers, units [128, 64, 32], epochs=20, activation=relu, regularization=l2, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Training model with 3 hidden layers, units [128, 64, 32], epochs=20, activation=relu, regularization=l2, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Training model with 3 hidden layers, units [128, 64, 32], epochs=20, activation=relu, regularization=l2, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Training model with 3 hidden layers, units [128, 64, 32], epochs=30, activation=sigmoid, regularization=None, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# Training model with 3 hidden layers, units [128, 64, 32], epochs=30, activation=sigmoid, regularization=None, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# Training model with 3 hidden layers, units [128, 64, 32], epochs=30, activation=sigmoid, regularization=None, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# Training model with 3 hidden layers, units [128, 64, 32], epochs=30, activation=sigmoid, regularization=l1, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# Training model with 3 hidden layers, units [128, 64, 32], epochs=30, activation=sigmoid, regularization=l1, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# Training model with 3 hidden layers, units [128, 64, 32], epochs=30, activation=sigmoid, regularization=l1, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# Training model with 3 hidden layers, units [128, 64, 32], epochs=30, activation=sigmoid, regularization=l2, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# Training model with 3 hidden layers, units [128, 64, 32], epochs=30, activation=sigmoid, regularization=l2, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# Training model with 3 hidden layers, units [128, 64, 32], epochs=30, activation=sigmoid, regularization=l2, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# Training model with 3 hidden layers, units [128, 64, 32], epochs=30, activation=relu, regularization=None, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Training model with 3 hidden layers, units [128, 64, 32], epochs=30, activation=relu, regularization=None, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Training model with 3 hidden layers, units [128, 64, 32], epochs=30, activation=relu, regularization=None, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Training model with 3 hidden layers, units [128, 64, 32], epochs=30, activation=relu, regularization=l1, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Training model with 3 hidden layers, units [128, 64, 32], epochs=30, activation=relu, regularization=l1, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Training model with 3 hidden layers, units [128, 64, 32], epochs=30, activation=relu, regularization=l1, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Training model with 3 hidden layers, units [128, 64, 32], epochs=30, activation=relu, regularization=l2, learning_rate=0.1
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Training model with 3 hidden layers, units [128, 64, 32], epochs=30, activation=relu, regularization=l2, learning_rate=0.01
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Training model with 3 hidden layers, units [128, 64, 32], epochs=30, activation=relu, regularization=l2, learning_rate=0.001
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step

# %%
# Visualize loss curves for best model by validation accuracy
best_model_info = max(results, key=lambda x: x['Accuracy'])
best_history = best_model_info['History']

plt.figure(figsize=(10,6))
plt.plot(best_history.history['loss'], label='Training Loss')
plt.plot(best_history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

print("Best hyperparameters:")
for k, v in best_model_info.items():
    if k != 'History':
        print(f"{k}: {v}")
# Out:
# Best hyperparameters:
# Hidden_Layers: 2
# Units: [128, 64]
# Epochs: 20
# Activation: relu
# Regularization: l2
# Learning_Rate: 0.001
# Accuracy: 0.847
# Precision: 0.704
# Recall: 0.43137254901960786

# %% [markdown]
# # Comments on the best hyperparameters
#
#
# ---
#
# ### 1. **Model Architecture:**
#
# - **Hidden Layers:** 2
# - **Units:** [128, 64]
# This is a moderately deep network, which balances complexity and overfitting risk. Two hidden layers are often sufficient to capture non-linear patterns without making the model too complex or prone to overfitting.
#
# ---
#
# ### 2. **Epochs: 20**
#
# - Training for 20 epochs is a reasonable choice to allow the model to learn well without overfitting, especially with regularization applied.
# - It suggests that the model converged well before 20 epochs or that more epochs didn’t improve performance significantly.
#
# ---
#
# ### 3. **Activation Function: ReLU**
#
# - ReLU is a standard choice for hidden layers due to its efficiency in training deep networks and ability to reduce vanishing gradient problems.
# - This aligns well with current deep learning best practices.
#
# ---
#
# ### 4. **Regularization: L2**
#
# - L2 regularization helps to prevent overfitting by penalizing large weights, encouraging the model to keep weights smaller.
# - The fact that regularization was beneficial means the dataset/model complexity benefits from some constraint to improve generalization.
#
# ---
#
# ### 5. **Learning Rate: 0.001**
#
# - A small learning rate allows the optimizer to make careful, incremental improvements.
# - This is typical and generally results in more stable and better convergence compared to larger learning rates.
#
# ---
#
# ### 6. **Performance Metrics:**
#
# | Metric    | Value | Comment                                                                                  |
# |----------|-------|------------------------------------------------------------------------------------------|
# | Accuracy | 0.847 | Strong overall correctness—model predicts 85% cases correctly. Good for imbalanced classes too. |
# | Precision| 0.704 | About 70% of predicted churners actually churn, indicating decent confidence in positive predictions. |
# | Recall   | 0.431 | Recall is relatively low (~43%), meaning the model misses more than half of the actual churners. This suggests a trade-off—model is conservative in flagging churners. |
#
# ---

# %%
# Rebuild the best model to evaluate on test set
best = best_model_info
model = build_model(best['Hidden_Layers'], list(best['Units']) + [0]*(3-best['Hidden_Layers']),
                    best['Activation'], reg_type=best['Regularization'], reg_value=0.001, learning_rate=best['Learning_Rate'])

model.fit(X_train, y_train, epochs=best['Epochs'], batch_size=64, verbose=0)

y_test_pred_prob = model.predict(X_test).ravel()
y_test_pred = (y_test_pred_prob > 0.5).astype(int)

test_acc = accuracy_score(y_test, y_test_pred)
test_prec = precision_score(y_test, y_test_pred)
test_rec = recall_score(y_test, y_test_pred)

print(f"Test Accuracy: {test_acc:.4f}, Precision: {test_prec:.4f}, Recall: {test_rec:.4f}")
# Out:
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# Test Accuracy: 0.8630, Precision: 0.7638, Recall: 0.4755

# %% [markdown]
# # Question 2 (Body Fat Dataset)

# %%
#Load the dataset
df = pd.read_csv('bodyfat.csv')
df
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# 1     58.7  37.3   23.4    30.5     28.9   18.2
# 2     59.6  38.9   24.0    28.8     25.2   16.6
# 3     60.1  37.3   22.8    32.4     29.4   18.2
# 4     63.2  42.2   24.0    32.2     27.7   17.7
# ..     ...   ...    ...     ...      ...    ...
# 247   49.6  34.8   21.5    25.6     25.7   18.5
# 248   59.6  40.8   23.2    35.2     28.6   20.1
# 249   60.3  37.3   21.5    31.3     27.2   18.0
# 250   56.0  41.6   22.7    30.5     29.4   19.8
# 251   59.3  42.2   24.6    33.7     30.0   20.9
#
# [252 rows x 15 columns]

# %%
# Features (exclude Density and BodyFat from inputs, since Density requires underwater weighing)
X = df.drop(['Density', 'BodyFat'], axis=1)  # use easier to measure features only
y = df['BodyFat']

# %%
#Split data into train and test set
X_train_val, X_test, y_train_val, y_test = train_test_split(
    X, y, test_size=0.1, random_state=42)

# Split train+val into 80% train, 10% val 
X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val, test_size=0.1111, random_state=42)

print(f'Train samples: {X_train.shape[0]}, Validation samples: {X_val.shape[0]}, Test samples: {X_test.shape[0]}')
# Out:
# Train samples: 200, Validation samples: 26, Test samples: 26

# %%
#Scale features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# %%
# Build model
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(X_train_scaled.shape[1],)))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1))  # regression output (body fat %)

# Compile model with Adam optimizer and learning rate = 0.1
optimizer = tf.keras.optimizers.Adam(learning_rate=0.1)
model.compile(optimizer=optimizer, loss='mse', metrics=['mae'])  # MSE loss and MAE metric

model.summary()
# Out:
# /home/student/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_163"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_489 (Dense)               │ (None, 128)            │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_490 (Dense)               │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_491 (Dense)               │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_492 (Dense)               │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,161 (47.50 KB)
#  Trainable params: 12,161 (47.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Train model
history = model.fit(
    X_train_scaled, y_train,
    validation_data=(X_val_scaled, y_val),
    epochs=50,   # you can adjust epochs as needed
    batch_size=32,
    verbose=1
)
# Out:
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - loss: 480.9232 - mae: 18.2602
# 2025-07-31 11:43:43.313413: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_26', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-07-31 11:43:43.613988: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_26', 12 bytes spill stores, 12 bytes spill loads
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 589ms/step - loss: 475.4782 - mae: 18.1661 - val_loss: 683.9138 - val_mae: 20.1520
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 420.3933 - mae: 15.7056 - val_loss: 384.8918 - val_mae: 17.1044
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 290.3244 - mae: 15.1740 - val_loss: 175.7591 - val_mae: 11.2154
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 130.3392 - mae: 9.0917 - val_loss: 137.4632 - val_mae: 10.1988
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 91.3407 - mae: 7.7416 - val_loss: 86.8785 - val_mae: 7.7631
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 72.3802 - mae: 6.8940 - val_loss: 84.6136 - val_mae: 8.0949
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 45.1932 - mae: 5.4770 - val_loss: 90.1332 - val_mae: 7.1810
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 43.1273 - mae: 5.1806 - val_loss: 52.3880 - val_mae: 5.9921
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 28.7190 - mae: 4.3549 - val_loss: 51.9975 - val_mae: 5.9920
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 33.9396 - mae: 4.7057 - val_loss: 51.2572 - val_mae: 5.7069
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 26.1231 - mae: 4.1266 - val_loss: 52.6341 - val_mae: 5.8618
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 22.0553 - mae: 3.7542 - val_loss: 42.6655 - val_mae: 5.3073
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 20.3057 - mae: 3.6175 - val_loss: 43.8916 - val_mae: 5.2757
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 20.4469 - mae: 3.6102 - val_loss: 37.6086 - val_mae: 5.0891
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 18.9334 - mae: 3.4750 - val_loss: 34.3046 - val_mae: 4.7252
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 19.8882 - mae: 3.5809 - val_loss: 41.7902 - val_mae: 4.9825
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 16.8050 - mae: 3.2940 - val_loss: 39.1816 - val_mae: 5.4482
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 22.4664 - mae: 3.7436 - val_loss: 32.6172 - val_mae: 4.8091
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 18.2542 - mae: 3.2795 - val_loss: 35.0063 - val_mae: 4.5786
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 18.4978 - mae: 3.4953 - val_loss: 40.9236 - val_mae: 5.2075
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 16.9408 - mae: 3.2163 - val_loss: 37.9715 - val_mae: 5.0511
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 21.3678 - mae: 3.6135 - val_loss: 27.9371 - val_mae: 4.3070
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 17.5542 - mae: 3.4149 - val_loss: 27.6374 - val_mae: 4.3663
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 17.2480 - mae: 3.2841 - val_loss: 37.1142 - val_mae: 4.7816
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 17.1672 - mae: 3.2634 - val_loss: 35.9810 - val_mae: 4.8349
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 16.6195 - mae: 3.2307 - val_loss: 40.7714 - val_mae: 4.9557
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 15.2108 - mae: 3.2423 - val_loss: 32.6080 - val_mae: 4.6185
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 26.4823 - mae: 3.9132 - val_loss: 31.0354 - val_mae: 4.8850
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 22.3988 - mae: 3.8093 - val_loss: 42.9697 - val_mae: 5.3597
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 29.3604 - mae: 4.1418 - val_loss: 34.4705 - val_mae: 4.9250
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 17.8577 - mae: 3.4082 - val_loss: 46.7721 - val_mae: 5.2678
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 14.1368 - mae: 2.9410 - val_loss: 36.6018 - val_mae: 5.0449
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 16.1357 - mae: 3.1544 - val_loss: 49.1515 - val_mae: 5.4208
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 15.7875 - mae: 3.2805 - val_loss: 39.7559 - val_mae: 5.2021
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 14.7341 - mae: 3.1074 - val_loss: 51.2668 - val_mae: 5.1362
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 16.5290 - mae: 3.2277 - val_loss: 33.7653 - val_mae: 4.5532
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 14.6738 - mae: 3.1356 - val_loss: 38.0620 - val_mae: 5.2918
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 20.1613 - mae: 3.5346 - val_loss: 47.7214 - val_mae: 5.0961
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 15.5474 - mae: 3.1989 - val_loss: 65.3138 - val_mae: 5.4680
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 14.7515 - mae: 2.9968 - val_loss: 52.7599 - val_mae: 5.1954
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 16.1882 - mae: 3.1183 - val_loss: 43.6131 - val_mae: 5.0846
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 13.3423 - mae: 2.9173 - val_loss: 37.5495 - val_mae: 5.2064
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 13.2810 - mae: 2.9131 - val_loss: 36.7978 - val_mae: 4.8168
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 13.1343 - mae: 2.8519 - val_loss: 47.5859 - val_mae: 5.5034
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 13.6017 - mae: 2.9427 - val_loss: 69.3143 - val_mae: 5.3510
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 15.5770 - mae: 3.1258 - val_loss: 75.0831 - val_mae: 5.9218
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 14.1952 - mae: 2.9478 - val_loss: 57.5053 - val_mae: 5.8242
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 13.9431 - mae: 2.9239 - val_loss: 51.6647 - val_mae: 5.6354
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 14.7634 - mae: 3.0306 - val_loss: 48.1152 - val_mae: 5.4897
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 13.7933 - mae: 2.8904 - val_loss: 50.9293 - val_mae: 5.5238

# %%
#Plot Loss over Epochs
plt.figure(figsize=(10,6))
plt.plot(history.history['loss'], label='Training Loss (MSE)')
plt.plot(history.history['val_loss'], label='Validation Loss (MSE)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.show()

# %%
#Evaluate on Test Data
test_loss, test_mae = model.evaluate(X_test_scaled, y_test)
print(f'Test MSE: {test_loss:.4f}, Test MAE: {test_mae:.4f}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 16.3921 - mae: 3.3724
# Test MSE: 16.3921, Test MAE: 3.3724
